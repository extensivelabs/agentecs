# %% [markdown]
# # Task Dispatch - Interactive AgentECS Demo
#
# This notebook demonstrates how AgentECS works through a dynamic task dispatch system.
#
# **What you'll see:**
# - How entities, components, and systems work together
# - Dynamic agent spawning and cleanup
# - Multi-turn LLM reasoning over multiple ticks
# - User interaction when agents need clarification
#
# ## Prerequisites
#
# ```bash
# # Install dependencies
# pip install agentecs[llm,notebook]
#
# # Set your API key
# export ANTHROPIC_API_KEY=your_key_here
# ```

# %% [markdown]
# ## Setup
#
# Import modules and configure the environment:

# %%
import os

from components import AgentState, Task, TaskQueue, TaskStatus
from systems import (
    agent_cleanup_system,
    agent_processing_system,
    task_assignment_system,
)

from agentecs import World

# Check API key
if not os.getenv("ANTHROPIC_API_KEY"):
    print("⚠️  Warning: ANTHROPIC_API_KEY not set!")
    print("Set it with: os.environ['ANTHROPIC_API_KEY'] = 'your_key_here'")
else:
    print("✅ API key configured")
# Out:
# ✅ API key configured

# %% [markdown]
# ## Define Tasks
#
# These tasks are intentionally designed to trigger agent questions, demonstrating the ASK_USER functionality:

# %%
# Tasks that will likely require user input
DEMO_TASKS = [
    "Plan a vacation for me",  # Will ask: where? when? budget?
    "Recommend a book",  # Will ask: genres? fiction/non-fiction?
    "Write a short story",  # Will ask: genre? length? theme?
    "Calculate the tip for a $47.50 restaurant bill",  # Will ask: what percentage?
]

print(f"📋 {len(DEMO_TASKS)} tasks ready:")
for i, task in enumerate(DEMO_TASKS, 1):
    print(f"  {i}. {task}")
# Out:
# 📋 4 tasks ready:
#   1. Plan a vacation for me
#   2. Recommend a book
#   3. Write a short story
#   4. Calculate the tip for a $47.50 restaurant bill

# %% [markdown]
# ## Initialize the World
#
# Create the ECS World and register our three systems:

# %%
def setup_world(world):
    """Initialize world with tasks and systems."""
    queue = TaskQueue()
    for task_desc in DEMO_TASKS:
        queue.add_task(task_desc)

    world.set_singleton(queue)

    world.register_system(task_assignment_system)
    world.register_system(agent_processing_system)
    world.register_system(agent_cleanup_system)

    print(f"🌍 World initialized with {len(queue.tasks)} unassigned tasks")
    print("🔧 3 systems registered: TaskAssignment, AgentProcessing, AgentCleanup")
    return world


world = setup_world(World())
# Out:
# 🌍 World initialized with 4 unassigned tasks
# 🔧 3 systems registered: TaskAssignment, AgentProcessing, AgentCleanup

# %% [markdown]
# ## How the Systems Work
#
# The three systems process agents in parallel during each tick:
#
# ### 1. Task Assignment System
# ```
# For each unassigned task in queue:
#   1. Call LLM to generate specialized system prompt for task
#   2. Spawn agent entity with AgentState + Task components
#   3. Remove task from queue (now lives on agent entity)
# ```
#
# ### 2. Agent Processing System
# ```
# For each agent with (AgentState, Task):
#   If status == IN_PROGRESS:
#     1. Build message history from conversation
#     2. Add user response if provided
#     3. Call LLM with structured output (AgentResponse)
#     4. Handle response type:
#        - DEEP_THOUGHT: Add to history, keep thinking
#        - ASK_USER: Set question, change status to WAITING_FOR_INPUT
#        - FINAL_ANSWER: Set result, change status to COMPLETED
#     5. Write back updated AgentState and Task
# ```
#
# ### 3. Agent Cleanup System
# ```
# For each agent with (AgentState, Task):
#   If task.status == COMPLETED:
#     Destroy agent entity (frees resources)
# ```
#
# **Key insight**: All three systems run **in parallel** on the same snapshot of world state. Changes are buffered and merged at the tick boundary.

# %% [markdown]
# ## Helper Functions
#
# Functions to inspect world state between ticks:

# %%
def show_world_state():
    """Display current state of agents and tasks."""
    queue = world.singleton(TaskQueue)

    print("\n" + "=" * 60)
    print("📊 WORLD STATE")
    print("=" * 60)

    # Unassigned tasks in queue
    if queue and queue.tasks:
        print(f"\n📋 Unassigned tasks in queue: {len(queue.tasks)}")
        for task in queue.tasks[:3]:  # Show first 3
            print(f"   - {task.description[:50]}...")
    else:
        print("\n📋 Queue is empty (all tasks assigned)")

    # Active agents
    agents = list(world.query(AgentState, Task))
    if agents:
        print(f"\n🤖 Active agents: {len(agents)}")
        for entity, agent_state, task in agents:
            status_emoji = {
                TaskStatus.IN_PROGRESS: "⚙️",
                TaskStatus.WAITING_FOR_INPUT: "❓",
                TaskStatus.COMPLETED: "✅",
            }.get(task.status, "❔")

            print(f"   Agent {entity.index}: {status_emoji} {task.status.value}")
            print(f"      Task: {task.description[:40]}...")
            print(f"      Iterations: {agent_state.iteration_count}")

            if task.status == TaskStatus.WAITING_FOR_INPUT:
                print(f"      ❓ Question: {task.user_query}")
            elif task.status == TaskStatus.COMPLETED:
                print(f"      ✅ Result: {task.result[:50]}...")
    else:
        print("\n🤖 No active agents")

    print("=" * 60 + "\n")


def get_waiting_agents():
    """Get agents waiting for user input."""
    waiting = []
    for entity, agent_state, task in world.query(AgentState, Task):
        if task.status == TaskStatus.WAITING_FOR_INPUT:
            waiting.append((entity, agent_state, task))
    return waiting


print("✅ Helper functions defined")
# Out:
# ✅ Helper functions defined

# %% [markdown]
# ## Tick 1: Task Assignment
#
# The first tick will:
# 1. **TaskAssignmentSystem** finds unassigned tasks in the queue
# 2. For each task, generates a specialized system prompt via LLM
# 3. Spawns an agent entity with `AgentState` and `Task` components
# 4. Removes task from queue (it now lives on the agent entity!)
#
# This demonstrates **dynamic entity spawning** in ECS.

# %%
print("🎬 TICK 1: Running task assignment...\n")

# Run one tick
await world.tick_async()

# Show what happened
show_world_state()
# Out:
# 🎬 TICK 1: Running task assignment...
#
# Built execution plan with 1 groups
# (0 dev systems isolated, 3 normal systems grouped)
# Dev Systems: []
# Normal Systems: ['task_assignment_system', 'agent_processing_system', 'agent_cleanup_system']
# ✨ Spawned agent for task: b7f59a6e... (Plan a vacation for me...)
# ✨ Spawned agent for task: 3a7bb21a... (Recommend a book...)
# ✨ Spawned agent for task: 22f882a3... (Write a short story...)
# ✨ Spawned agent for task: 6022a80c... (Calculate the tip for a $47.50 restaurant bill...)
#
# ============================================================
# 📊 WORLD STATE
# ============================================================
#
# 📋 Queue is empty (all tasks assigned)
#
# 🤖 Active agents: 4
#    Agent 1000: ⚙️ in_progress
#       Task: Plan a vacation for me...
#       Iterations: 0
#    Agent 1001: ⚙️ in_progress
#       Task: Recommend a book...
#       Iterations: 0
#    Agent 1002: ⚙️ in_progress
#       Task: Write a short story...
#       Iterations: 0
#    Agent 1003: ⚙️ in_progress
#       Task: Calculate the tip for a $47.50 restauran...
#       Iterations: 0
# ============================================================

# %% [markdown]
# ## Tick 2: Initial Agent Processing
#
# The second tick will:
# 1. **AgentProcessingSystem** queries all entities with `(AgentState, Task)` components
# 2. For each agent in IN_PROGRESS status, calls Claude with:
#    - Agent's specialized system prompt
#    - Conversation history (empty on first call)
#    - Structured output model: `AgentResponse(reasoning, response_type, message)`
# 3. Handles responses:
#    - **DEEP_THOUGHT**: Adds to conversation history, continues thinking
#    - **ASK_USER**: Sets question, waits for input
#    - **FINAL_ANSWER**: Marks task complete
#
# This demonstrates **multi-turn reasoning** and **structured LLM output**.

# %%
print("🎬 TICK 2: Running agent processing...\n")

await world.tick_async()

show_world_state()
# Out:
# 🎬 TICK 2: Running agent processing...
#
# ❓ Agent 1000 asks: I'd be happy to help plan your vacation! To create the best itinerary for you, could you share: 1) Where would you like to go (or what type of experience interests you - beach, city, adventure, etc.)? 2) When are you traveling and for how long? 3) What's your budget range? 4) How many people are traveling, and are there any special interests or requirements I should know about?
# ❓ Agent 1001 asks: I'd love to recommend a book for you! To find the perfect match, could you share: What genres do you typically enjoy? Are there any recent books you've loved? What mood or themes are you interested in exploring right now?
# ✅ Agent 1002 completed: **The Last Lighthouse Keeper**
#
# The fog rolled in thick that...
# ✅ Agent 1003 completed: Here are the tip calculations for your $47.50 restaurant bil...
#
# ============================================================
# 📊 WORLD STATE
# ============================================================
#
# 📋 Queue is empty (all tasks assigned)
#
# 🤖 Active agents: 4
#    Agent 1000: ❓ waiting_for_input
#       Task: Plan a vacation for me...
#       Iterations: 1
#       ❓ Question: I'd be happy to help plan your vacation! To create the best itinerary for you, could you share: 1) Where would you like to go (or what type of experience interests you - beach, city, adventure, etc.)? 2) When are you traveling and for how long? 3) What's your budget range? 4) How many people are traveling, and are there any special interests or requirements I should know about?
#    Agent 1001: ❓ waiting_for_input
#       Task: Recommend a book...
#       Iterations: 1
#       ❓ Question: I'd love to recommend a book for you! To find the perfect match, could you share: What genres do you typically enjoy? Are there any recent books you've loved? What mood or themes are you interested in exploring right now?
#    Agent 1002: ✅ completed
#       Task: Write a short story...
#       Iterations: 1
#       ✅ Result: **The Last Lighthouse Keeper**
#
# The fog rolled in ...
#    Agent 1003: ✅ completed
#       Task: Calculate the tip for a $47.50 restauran...
#       Iterations: 1
#       ✅ Result: Here are the tip calculations for your $47.50 rest...
# ============================================================

# %% [markdown]
# ## User Interaction: Answer Agent Questions
#
# If any agents are waiting for input, provide answers here.
#
# This demonstrates **external interaction** with the ECS - we query the world state and modify components directly.

# %%
waiting = get_waiting_agents()

if waiting:
    print(f"\n❓ {len(waiting)} agent(s) waiting for input:\n")

    for entity, _agent_state, task in waiting:
        print(f"\n🤖 Agent {entity.index} asks:")
        print(f"   {task.user_query}")
        print(f"   Task: {task.description}")

        # Get user response
        response = input("\nYour answer: ")

        # Inject response back into task - must write back!
        task.user_response = response
        task.status = TaskStatus.IN_PROGRESS
        world.set(entity, task)

        print(f"✅ Response recorded for Agent {entity.index}\n")
else:
    print("\n✅ No agents waiting for input")
# Out:
# ❓ 2 agent(s) waiting for input:
#
#
# 🤖 Agent 1000 asks:
#    I'd be happy to help plan your vacation! To create the best itinerary for you, could you share: 1) Where would you like to go (or what type of experience interests you - beach, city, adventure, etc.)? 2) When are you traveling and for how long? 3) What's your budget range? 4) How many people are traveling, and are there any special interests or requirements I should know about?
#    Task: Plan a vacation for me
# Your answer:  Instanbul in june
# ✅ Response recorded for Agent 1000
#
#
# 🤖 Agent 1001 asks:
#    I'd love to recommend a book for you! To find the perfect match, could you share: What genres do you typically enjoy? Are there any recent books you've loved? What mood or themes are you interested in exploring right now?
#    Task: Recommend a book
# Your answer:  i like neil stephensOn
# ✅ Response recorded for Agent 1001

# %% [markdown]
# ## Continue Processing: Run More Ticks
#
# Run this cell multiple times to advance the simulation.
#
# Each tick will:
# - Process agents that have user responses
# - Continue DEEP_THOUGHT chains
# - Ask more questions if needed
# - Complete tasks
# - Clean up finished agents
#
# This demonstrates the **iterative tick-based execution model** of ECS.

# %%
# Run one more tick
await world.tick_async()

show_world_state()

# Check for more waiting agents
waiting = get_waiting_agents()
if waiting:
    print(f"\n❗ {len(waiting)} agent(s) need your input - run the interaction cell above!")
else:
    active = sum(1 for _ in world.query(AgentState))
    if active == 0:
        print("\n🎉 All tasks completed!")
    else:
        print(f"\n⏳ {active} agent(s) still thinking...")
# Out:
# Cleaning up agent 1002 (task 22f882a3... completed)
# Cleaning up agent 1003 (task 6022a80c... completed)
# ❓ Agent 1000 asks: Great choice! Istanbul in June is wonderful with warm weather. To plan your trip properly, I need a few more details: How many days will you be staying? What's your approximate budget (total or per day)? How many people are traveling? And are there specific experiences you're interested in (history, food, shopping, nightlife, etc.)?
# ✅ Agent 1001 completed: Great choice! Neal Stephenson fans appreciate dense, intelle...
#
# ============================================================
# 📊 WORLD STATE
# ============================================================
#
# 📋 Queue is empty (all tasks assigned)
#
# 🤖 Active agents: 2
#    Agent 1000: ❓ waiting_for_input
#       Task: Plan a vacation for me...
#       Iterations: 2
#       ❓ Question: Great choice! Istanbul in June is wonderful with warm weather. To plan your trip properly, I need a few more details: How many days will you be staying? What's your approximate budget (total or per day)? How many people are traveling? And are there specific experiences you're interested in (history, food, shopping, nightlife, etc.)?
#    Agent 1001: ✅ completed
#       Task: Recommend a book...
#       Iterations: 2
#       ✅ Result: Great choice! Neal Stephenson fans appreciate dens...
# ============================================================
#
#
# ❗ 1 agent(s) need your input - run the interaction cell above!

# %% [markdown]
# ## Full Auto-Run Loop
#
# This cell runs ticks automatically until all tasks complete or we hit the limit.
#
# It will pause and ask for user input when agents have questions.

# %%
import asyncio

MAX_TICKS = 20
completed_tasks = []

world = setup_world(World())

for tick_num in range(MAX_TICKS):
    print(f"\n{'=' * 60}")
    print(f"⏱️  TICK {tick_num + 1}")
    print("=" * 60)

    # Save completed tasks before cleanup
    for _entity, _agent_state, task in world.query(AgentState, Task):
        if task.status == TaskStatus.COMPLETED and task not in completed_tasks:
            completed_tasks.append(task)

    # Run tick
    await world.tick_async()

    # Handle user queries
    waiting = get_waiting_agents()
    if waiting:
        print(f"\n❓ {len(waiting)} agent(s) need input:\n")

        for entity, _agent_state, task in waiting:
            print(f"🤖 Agent {entity.index}: {task.user_query}")
            print(f"   (Task: {task.description})")
            response = input("   Your answer: ")

            # Must write back mutations!
            task.user_response = response
            task.status = TaskStatus.IN_PROGRESS
            world.set(entity, task)
            print()

    # Check if done
    active_agents = sum(1 for _ in world.query(AgentState))
    if active_agents == 0:
        print(f"\n✅ All tasks completed after {tick_num + 1} ticks!")
        break

    await asyncio.sleep(0.5)  # Brief pause for readability

# Final summary
print("\n" + "=" * 60)
print("📊 FINAL RESULTS")
print("=" * 60)

for i, task in enumerate(completed_tasks, 1):
    print(f"\n{i}. {task.description}")
    print(f"   ✅ {task.result}")

print("\n" + "=" * 60)
# Out:
# 🌍 World initialized with 4 unassigned tasks
# 🔧 3 systems registered: TaskAssignment, AgentProcessing, AgentCleanup
#
# ============================================================
# ⏱️  TICK 1
# ============================================================
# ✨ Spawned agent for task: 5a1da800... (Plan a vacation for me...)
# ✨ Spawned agent for task: 84c9d43f... (Recommend a book...)
# ✨ Spawned agent for task: 6191d8c6... (Write a short story...)
# ✨ Spawned agent for task: a41df511... (Calculate the tip for a $47.50 restaurant bill...)
#
# ============================================================
# ⏱️  TICK 2
# ============================================================
# ❓ Agent 1000 asks: I'd love to help plan your vacation! To create the perfect trip for you, could you share: Where would you like to go (or what type of destination interests you)? When and for how long? What's your budget range? Who's traveling (solo/couple/family/group)? And what are your main interests (beach relaxation, adventure, culture, food, etc.)?
# ❓ Agent 1001 asks: I'd love to help you find the perfect book! To give you the best recommendation, could you tell me: What genres do you typically enjoy? Are there any recent books you've loved? What kind of reading mood are you in right now (something light and fun, thought-provoking, emotional, adventurous)?
# ✅ Agent 1002 completed: **The Last Customer**
#
# The bell above the door chimed at 11:...
# ✅ Agent 1003 completed: Here are your tip calculations for a $47.50 restaurant bill:...
#
# ❓ 2 agent(s) need input:
#
# 🤖 Agent 1000: I'd love to help plan your vacation! To create the perfect trip for you, could you share: Where would you like to go (or what type of destination interests you)? When and for how long? What's your budget range? Who's traveling (solo/couple/family/group)? And what are your main interests (beach relaxation, adventure, culture, food, etc.)?
#    (Task: Plan a vacation for me)
#    Your answer:  instanbul in summer
# 🤖 Agent 1001: I'd love to help you find the perfect book! To give you the best recommendation, could you tell me: What genres do you typically enjoy? Are there any recent books you've loved? What kind of reading mood are you in right now (something light and fun, thought-provoking, emotional, adventurous)?
#    (Task: Recommend a book)
#    Your answer:  i have read all Of neil stephensOn
# ============================================================
# ⏱️  TICK 3
# ============================================================
# Cleaning up agent 1002 (task 6191d8c6... completed)
# Cleaning up agent 1003 (task a41df511... completed)
# ❓ Agent 1000 asks: Great choice! Istanbul is wonderful in summer. To create your perfect itinerary, I need a few more details: How many days will you be visiting? What's your total budget? Who's traveling with you? And what interests you most - historical sites, food tours, shopping, nightlife, or a mix?
# ✅ Agent 1001 completed: Excellent! Since you've devoured all of Neal Stephenson's wo...
#
# ❓ 1 agent(s) need input:
#
# 🤖 Agent 1000: Great choice! Istanbul is wonderful in summer. To create your perfect itinerary, I need a few more details: How many days will you be visiting? What's your total budget? Who's traveling with you? And what interests you most - historical sites, food tours, shopping, nightlife, or a mix?
#    (Task: Plan a vacation for me)
#    Your answer:  just surprise me
# ============================================================
# ⏱️  TICK 4
# ============================================================
# Cleaning up agent 1001 (task 84c9d43f... completed)
# ✅ Agent 1000 completed: 🌟 **YOUR SURPRISE ISTANBUL SUMMER ADVENTURE** 🌟
#
# **Duration:...
#
# ============================================================
# ⏱️  TICK 5
# ============================================================
# Cleaning up agent 1000 (task 5a1da800... completed)
#
# ✅ All tasks completed after 5 ticks!
#
# ============================================================
# 📊 FINAL RESULTS
# ============================================================
#
# 1. Write a short story
#    ✅ **The Last Customer**
#
# The bell above the door chimed at 11:47 PM, thirteen minutes before closing. Marcus looked up from wiping down the espresso machine, already calculating how much longer this would take. The customer was a woman in her sixties, wearing a rain-soaked coat that dripped onto the café's worn floorboards.
#
# "Are you still open?" she asked, breathless.
#
# Marcus gestured to the chairs already stacked on tables. "Technically."
#
# "I just need coffee. Black. Please." Something in her voice—a tremor, a desperate edge—made him pause mid-excuse.
#
# "Sure. Have a seat."
#
# She chose the only unstacked table, the wobbly one by the window that Marcus kept meaning to fix. While the machine hissed and gurgled, he watched her in the mirror behind the counter. She sat perfectly still, staring at her hands folded on the table like she was holding something invisible and precious between them.
#
# Marcus brought the coffee over. Up close, he noticed her eyes were red-rimmed, her silver hair escaping from a bun in wild tendrils.
#
# "Three fifty," he said, but she was already holding out a five.
#
# "Keep it."
#
# He should have gone back to closing duties. Instead, he found himself asking, "Rough night?"
#
# She laughed—a sound like breaking glass. "Rough forty years." She wrapped both hands around the mug. "I'm sorry. You don't need to hear this."
#
# "It's okay. I'm not in a rush." The lie surprised him. He was always in a rush—to close, to get home, to check his phone, to be anywhere but here in this failing café his father had left him.
#
# "I just came from the hospital," she said. "My husband died three hours ago."
#
# Marcus's throat tightened. "I'm so sorry."
#
# "Everyone keeps saying that." She took a sip. "But you know what's strange? I feel... relieved. Is that terrible?"
#
# He pulled out the chair across from her and sat down. "I don't know."
#
# "We had forty-two years together. Forty-two years of him criticizing every meal I cooked, every friend I made, every dream I mentioned out loud. He never hit me. Never screamed. Just this constant, dripping disappointment that made me smaller and smaller until I could barely remember who I was before him."
#
# She looked up at Marcus with fierce, bright eyes. "And now he's gone, and I'm seventy-three years old, and I walked out of that hospital and realized I have absolutely no idea what to do with freedom."
#
# Marcus thought about the café, how he'd been running it for six years since his father's stroke. How he'd put his architecture degree in a drawer and picked up an apron. How every day felt like honoring a debt he'd never agreed to.
#
# "What would you do?" he asked quietly. "If you could do anything?"
#
# Her face transformed. "There's a pottery studio three blocks from my house. I walk past it every day. They have classes for beginners." She laughed again, lighter this time. "Isn't that silly? Seventy-three and wanting to play with clay like a child."
#
# "That's not silly."
#
# "What about you?" She tilted her head. "What would you do?"
#
# The answer came immediately, from some locked room inside him. "I'd design buildings. Beautiful ones. Places that make people feel something when they walk inside."
#
# "So why don't you?"
#
# "It's complicated."
#
# "It always is." She finished her coffee and stood, steadier now. "Thank you for this. For listening. For staying open."
#
# "I'm glad you came in."
#
# At the door, she turned back. "That studio has an open house next Tuesday. I'm going to walk in instead of past. You should think about what door you're going to walk through."
#
# The bell chimed as she left. Marcus watched her disappear into the rain, shoulders squared, walking with purpose.
#
# He looked around the empty café—the peeling paint, the ancient espresso machine, the wobbly table. His father had loved this place with an intensity that left no room for anything else, including Marcus's own dreams. But his father was gone. Had been gone, really, even before the stroke took his words and left only those demanding eyes.
#
# Marcus pulled out his phone. His old professor's email was still in his contacts. He started typing: "Hi Professor Chen. I know it's been six years, but I'm wondering if that offer to review my portfolio still stands..."
#
# He hesitated, finger hovering over send.
#
# Then he thought of the woman, seventy-three and finally free, walking toward a pottery studio in the rain.
#
# He pressed send.
#
# The café would close eventually—maybe he'd sell it, maybe he'd let it go. But tonight, for the first time in years, Marcus felt like he'd actually opened something.
#
# He finished cleaning quickly, turned off the lights, and locked the door at 12:03 AM. As he walked to his car, he noticed the rain had stopped. Above the city's glow, a few stubborn stars pushed through the clouds.
#
# Marcus smiled and headed home, already sketching buildings in his mind.
#
# 2. Calculate the tip for a $47.50 restaurant bill
#    ✅ Here are your tip calculations for a $47.50 restaurant bill:
#
# **15% Tip (Adequate Service):**
# - Tip amount: $7.13
# - Total bill: $54.63
#
# **18% Tip (Good Service):**
# - Tip amount: $8.55
# - Total bill: $56.05
#
# **20% Tip (Excellent Service):**
# - Tip amount: $9.50
# - Total bill: $57.00
#
# The 20% option gives you a nice round total of $57.00, which makes payment convenient. Choose the percentage that best reflects the quality of service you received!
#
# 3. Recommend a book
#    ✅ Excellent! Since you've devoured all of Neal Stephenson's work, you clearly appreciate ambitious, intellectually dense science fiction with intricate world-building and deep technical detail. Here are three recommendations that should satisfy that same craving:
#
# **Top Recommendation: "Anathem" by... wait, you've read that! Let me give you:**
#
# **"The Three-Body Problem" by Liu Cixin** (translated by Ken Liu)
# This Chinese sci-fi masterpiece shares Stephenson's love of hard science, grand scope, and mind-bending concepts. It weaves together the Cultural Revolution, virtual reality, physics, and first contact with an alien civilization in ways that are both intellectually rigorous and narratively gripping. Like Stephenson, Liu doesn't shy away from complex scientific explanations, and the trilogy expands into truly cosmic scales. If you loved the Baroque Cycle's historical depth mixed with *Seveneves'* hard SF, this is your next obsession.
#
# **"Blindsight" by Peter Watts**
# A darker, tighter alternative - this is hard SF that explores consciousness, intelligence, and what it means to be human through a first-contact scenario. Watts is a marine biologist, and his scientific rigor rivals Stephenson's, but in a more philosophically unsettling package. Think *Snow Crash* meets *Solaris*.
#
# **"The Peripheral" by William Gibson**
# Gibson's recent work has evolved into something remarkably Stephenson-esque - complex time-travel mechanics, near-future technology, intricate plotting, and that same ability to make you feel like you're glimpsing our actual future.
#
# Which direction appeals most - epic scope, philosophical darkness, or near-future complexity?
#
# 4. Plan a vacation for me
#    ✅ 🌟 **YOUR SURPRISE ISTANBUL SUMMER ADVENTURE** 🌟
#
# **Duration:** 6 Days / 5 Nights in July/August
# **Budget:** ~$1,800-2,200 per person (moderate comfort)
# **Vibe:** Cultural immersion + culinary delights + hidden gems
#
# ---
#
# ## **DAY-BY-DAY ITINERARY**
#
# **DAY 1 - Arrival & Sultanahmet Magic**
# - Morning: Arrive at Istanbul Airport (IST), take Havaist shuttle to Sultanahmet (€10)
# - Check into boutique hotel in Sultanahmet district
# - Afternoon: Blue Mosque & Hippodrome stroll
# - Evening: Sunset at Sultanahmet Square, dinner at Balkan Lokantası (traditional Turkish)
#
# **DAY 2 - Byzantine & Ottoman Wonders**
# - Morning: Hagia Sophia (arrive early, 9 AM, €25 entry)
# - Mid-day: Basilica Cistern (€10)
# - Lunch: Sefa Restaurant (köfte & pide)
# - Afternoon: Topkapi Palace & Harem (€20 + €10)
# - Evening: Rooftop dinner at Seven Hills Restaurant with mosque views
#
# **DAY 3 - Grand Bazaar & Spice Market**
# - Morning: Grand Bazaar exploration (haggling practice!)
# - Lunch: Street food - simit, midye dolma (stuffed mussels)
# - Afternoon: Spice Bazaar & Rustem Pasha Mosque (hidden gem with stunning tiles)
# - Evening: Bosphorus sunset cruise (€15-25), dinner on the boat
#
# **DAY 4 - Asian Side Adventure**
# - Morning: Ferry to Kadıköy (€1 - iconic Istanbul experience!)
# - Explore Kadıköy Market & Moda neighborhood
# - Lunch: Çiya Sofrası (amazing regional Anatolian cuisine)
# - Afternoon: Walk along Moda coastline, tea at a seaside café
# - Evening: Return to European side, dinner in Karaköy at Karaköy Lokantası
#
# **DAY 5 - Trendy Istanbul**
# - Morning: Dolmabahçe Palace (€15)
# - Lunch: Beşiktaş fish sandwiches by the water (€5)
# - Afternoon: Explore Galata Tower (€10) & İstiklal Avenue shopping
# - Evening: Dinner in Asmalı Mescit (meyhane experience), then drinks at rooftop bar in Beyoğlu
#
# **DAY 6 - Hammam & Departure**
# - Morning: Traditional Turkish bath at Çemberlitaş Hamamı (€40-60)
# - Lunch: Final kebab at Hamdi Restaurant with Golden Horn views
# - Afternoon: Last-minute shopping or café time in Balat (colorful Instagram-worthy neighborhood)
# - Evening: Airport shuttle, departure
#
# ---
#
# ## **ACCOMMODATION**
#
# **Mid-Range Boutique ($80-120/night):**
# - **Sura Hagia Sophia Hotel** - Stunning terrace views, perfect location
# - **Hotel Arcadia Blue Istanbul** - Rooftop breakfast with mosque views
# - **Alternative:** Airbnb in Galata/Karaköy for local vibe ($70-100/night)
#
# ---
#
# ## **COST BREAKDOWN**
#
# - **Flights:** $600-900 (varies by origin)
# - **Accommodation:** $400-600 (5 nights)
# - **Food:** $300-400 (mix of street food & restaurants)
# - **Activities & Entries:** $150-200
# - **Transportation:** $50-100 (public transit + taxis)
# - **Shopping/Misc:** $200-300
# - **TOTAL:** ~$1,800-2,200
#
# ---
#
# ## **INSIDER TIPS**
#
# 🌡️ **Summer Reality:** July-August is HOT (85-95°F). Early mornings & evenings are best for sightseeing.
#
# 🎫 **Skip Lines:** Buy Museum Pass Istanbul (€100) for priority access to major sites
#
# 🚇 **Get Istanbulkart:** Rechargeable transit card (saves 50% vs tokens)
#
# 🍽️ **Food Musts:**
# - Breakfast spreads (kahvaltı)
# - Fresh pomegranate juice
# - Baklava from Hafız Mustafa
# - Late-night kokoreç (adventurous eaters!)
#
# 👗 **Dress Code:** Modest clothing for mosques (scarves provided for women)
#
# 💰 **Money:** Turkish Lira preferred. ATMs widely available. Credit cards accepted at most places.
#
# 🗣️ **Language:** Learn basics - "Merhaba" (hello), "Teşekkürler" (thank you)
#
# ⚠️ **Safety:** Istanbul is generally safe. Watch for pickpockets in crowded areas. Agree on taxi fares beforehand or use BiTaksi app.
#
# 📱 **Stay Connected:** Get Turkish SIM card at airport (Turkcell, €20 for tourist package)
#
# ---
#
# ## **BONUS SURPRISES**
#
# - Take the ferry at sunset for magical light on the city
# - Try a "nargile" (hookah) at a traditional café
# - Visit during a call to prayer for an unforgettable atmospheric moment
# - Explore Balat's rainbow houses early morning (fewer crowds)
#
# **Best Time to Book:** 2-3 months ahead for better flight deals. Summer is peak season!
#
# This plan balances iconic landmarks with authentic local experiences, giving you the essence of Istanbul - where East meets West, ancient meets modern, and every corner tells a story. Enjoy your adventure! 🇹🇷✨
#
# ============================================================

# %% [markdown]
# ## Key ECS Concepts Demonstrated
#
# ### 1. Entities are Just IDs
# - Agents are lightweight `EntityId` objects
# - No behavior, just identity
#
# ### 2. Components are Pure Data
# - `Task`: description, status, result, user interaction state
# - `AgentState`: system prompt, conversation history, iteration count
# - `TaskQueue`: list of unassigned tasks (singleton)
#
# ### 3. Systems Define Behavior
# - Query entities with specific component combinations
# - Read components, compute, write back
# - Example: `world(AgentState, Task)` gets agents with tasks
#
# ### 4. Task Component Lifecycle
# ```
# UNASSIGNED: Lives in TaskQueue singleton
#      ↓
# IN_PROGRESS: Moves to agent entity (spawned with AgentState), agent working
#      ↓
# WAITING_FOR_INPUT: Agent has question (pauses for user)
#      ↓
# COMPLETED: Task done
#      ↓
# Agent destroyed, components removed
# ```
#
# ### 5. No Cross-Referencing Needed
# - Task and AgentState paired on same entity
# - Query returns both: `world(AgentState, Task)`
# - Clean, natural ECS pattern
#
# ### 6. Dynamic Entity Management
# - Agents spawned on-demand (TaskAssignmentSystem)
# - Agents destroyed when done (AgentCleanupSystem)
# - Components move between entities (Task from queue to agent)

# %% [markdown]
# ## Experiment: Add New Tasks
#
# Try adding your own tasks and running more ticks!

# %%
# Get the queue and add new tasks
queue = world.singleton(TaskQueue)

new_tasks = [
    "Explain quantum computing",
    "Suggest a recipe for dinner",
]

for task_desc in new_tasks:
    queue.add_task(task_desc)
    print(f"➕ Added: {task_desc}")

world.set_singleton(queue)
print(f"\n📋 Queue now has {len(queue.tasks)} unassigned tasks")
print("\n▶️  Run tick cells above to process them!")
# Out:
# ➕ Added: Explain quantum computing
# ➕ Added: Suggest a recipe for dinner
#
# 📋 Queue now has 2 unassigned tasks
#
# ▶️  Run tick cells above to process them!
